# %% [markdown]
# <h1>One Layer NN

# %%
import matplotlib.pyplot as plt

# %%
val_acc_history = [0.0952, 0.4181, 0.4515, 0.4608, 0.4939, 0.5081, 0.5029, 0.5073, 0.4756, 0.5138, 0.5112, 0.522, 0.5311, 0.5207, 0.5254, 0.5237]

# %%
train_acc_history = [0.11, 0.417, 0.474, 0.522, 0.543, 0.579, 0.613, 0.604, 0.547, 0.654, 0.661, 0.702, 0.718, 0.711, 0.7, 0.742]

# %%
plt.plot(val_acc_history)
plt.ylabel('val accuracy history')
# Out:
# Text(0, 0.5, 'val accuracy history')

# %%
plt.plot(train_acc_history)
plt.ylabel('train accuracy history')
# Out:
# Text(0, 0.5, 'train accuracy history')
