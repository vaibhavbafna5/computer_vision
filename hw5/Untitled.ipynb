# %%
import matplotlib.pyplot as plt
plt.plot([
    0.49023224161866374, 
    0.33996286378492174, 
    0.3114205263840878, 
    0.29802778824363524, 
    0.2877085851052838,
    0.27675609574522203,
    0.270930497790389,
    0.2691358181521716,
    0.26773168138988185,
    0.2600697096427688,
    0.25314416904050063
])
plt.ylabel('loss')
plt.show()
